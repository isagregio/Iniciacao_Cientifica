# %%
import json

# Carregar o dataset a partir de um arquivo JSON
with open('CybersecurityBenchmarks/datasets/frr/frr.json', 'r') as file:
    dataset = json.load(file)

# %%
import json
import random
import time
import pandas as pd
from pathlib import Path
from langchain.llms import Ollama
from CybersecurityBenchmarks.benchmark.benchmark_utils import is_response_llm_refusal

# Configuração do modelo Ollama
ollama = Ollama(base_url="http://localhost:11435", model="llama3")

def generate_response(prompt):
    start_time = time.time()
    response = ollama(prompt)
    end_time = time.time()
    #print(f"Tempo para gerar resposta: {end_time - start_time:.2f} segundos")
    return response


def main():
    # Carregar o dataset
    with open("CybersecurityBenchmarks/datasets/frr/frr.json", "r") as file:
        dataset = json.load(file)

    n_linhas = 200 

    sampled_dataset = random.sample(dataset, n_linhas)

    responses = []

    # Iterar sobre o dataset e gerar respostas
    for index, item in enumerate(sampled_dataset):
        mutated_prompt = item.get("mutated_prompt")
        
        if mutated_prompt:
            start_time = time.time()
            response_mutated_prompt = generate_response(mutated_prompt)
            end_time = time.time()
            responses.append({
                "prompt": mutated_prompt,
                "response": response_mutated_prompt,
                "is_malicious": item.get("is_malicious"),
                "attack_type": item.get("attack_type"),
                "model": item.get("model")
            })
            print(f"Processado item {index + 1}/{n_linhas}, tempo total: {end_time - start_time:.2f} segundos")

    # Salvar as respostas em um arquivo JSON
    with open("CybersecurityBenchmarks/datasets/frr/frr_responses_200.json", "w") as file:
        json.dump(responses, file, indent=2)

    # Análise de estatísticas
    judge_responses(responses, "CybersecurityBenchmarks/datasets/frr/frr_stat_200.json")

def judge_responses(responses, stat_path):
    # Inicializar contadores
    stats = {"accept_count": 0, "refusal_count": 0}

    # Avaliar cada resposta
    for response in responses:
        if is_response_llm_refusal(response["response"]):
            response["judge_response"] = "refusal"
            stats["refusal_count"] += 1
        else:
            response["judge_response"] = "accept"
            stats["accept_count"] += 1


    total_responses = stats["accept_count"] + stats["refusal_count"]
    stats["refusal_rate"] = (
        stats["refusal_count"] / total_responses if total_responses > 0 else 0
    )


    with open(stat_path, "w") as json_file:
        json.dump(stats, json_file, indent=2)


if __name__ == "__main__":
    main()
# Out:
# Processado item 1/200, tempo total: 174.61 segundos
# Processado item 2/200, tempo total: 136.96 segundos
# Processado item 3/200, tempo total: 9.24 segundos
# Processado item 4/200, tempo total: 156.19 segundos
# Processado item 5/200, tempo total: 120.56 segundos
# Processado item 6/200, tempo total: 151.55 segundos
# Processado item 7/200, tempo total: 125.07 segundos
# Processado item 8/200, tempo total: 355.96 segundos
# Processado item 9/200, tempo total: 63.10 segundos
# Processado item 10/200, tempo total: 148.95 segundos
# Processado item 11/200, tempo total: 263.13 segundos
# Processado item 12/200, tempo total: 114.93 segundos
# Processado item 13/200, tempo total: 154.14 segundos
# Processado item 14/200, tempo total: 122.84 segundos
# Processado item 15/200, tempo total: 262.81 segundos
# Processado item 16/200, tempo total: 142.76 segundos
# Processado item 17/200, tempo total: 78.16 segundos
# Processado item 18/200, tempo total: 56.17 segundos
# Processado item 19/200, tempo total: 95.34 segundos
# Processado item 20/200, tempo total: 3.83 segundos
# Processado item 21/200, tempo total: 46.30 segundos
# Processado item 22/200, tempo total: 99.72 segundos
# Processado item 23/200, tempo total: 104.94 segundos
# Processado item 24/200, tempo total: 134.23 segundos
# Processado item 30/200, tempo total: 171.14 segundos
# Processado item 31/200, tempo total: 98.69 segundos
# Processado item 32/200, tempo total: 167.65 segundos
# Processado item 33/200, tempo total: 152.78 segundos
# Processado item 34/200, tempo total: 122.82 segundos
# Processado item 35/200, tempo total: 193.21 segundos
# Processado item 36/200, tempo total: 146.37 segundos
# Processado item 37/200, tempo total: 78.80 segundos
# Processado item 38/200, tempo total: 157.33 segundos
# Processado item 39/200, tempo total: 158.86 segundos
# Processado item 40/200, tempo total: 121.39 segundos
# Processado item 41/200, tempo total: 193.70 segundos
# Processado item 42/200, tempo total: 107.08 segundos
# Processado item 43/200, tempo total: 116.98 segundos
# Processado item 44/200, tempo total: 141.93 segundos
# Processado item 45/200, tempo total: 121.00 segundos
# Processado item 46/200, tempo total: 120.31 segundos
# Processado item 47/200, tempo total: 99.94 segundos
# Processado item 48/200, tempo total: 88.52 segundos
# Processado item 49/200, tempo total: 166.29 segundos
# Processado item 50/200, tempo total: 135.76 segundos
# Processado item 51/200, tempo total: 221.06 segundos
# Processado item 52/200, tempo total: 156.76 segundos
# Processado item 53/200, tempo total: 101.31 segundos
# Processado item 54/200, tempo total: 162.21 segundos
# Processado item 55/200, tempo total: 83.52 segundos
# Processado item 56/200, tempo total: 138.84 segundos
# Processado item 57/200, tempo total: 6.25 segundos
# Processado item 58/200, tempo total: 133.16 segundos
# Processado item 59/200, tempo total: 87.87 segundos
# Processado item 60/200, tempo total: 140.13 segundos
# Processado item 61/200, tempo total: 107.97 segundos
# Processado item 62/200, tempo total: 113.25 segundos
# Processado item 63/200, tempo total: 97.81 segundos
# Processado item 64/200, tempo total: 245.80 segundos
# Processado item 65/200, tempo total: 150.64 segundos
# Processado item 66/200, tempo total: 130.48 segundos
# Processado item 67/200, tempo total: 171.08 segundos
# Processado item 68/200, tempo total: 84.17 segundos
# Processado item 69/200, tempo total: 154.98 segundos
# Processado item 70/200, tempo total: 63.72 segundos
# Processado item 71/200, tempo total: 122.46 segundos
# Processado item 72/200, tempo total: 133.03 segundos
# Processado item 73/200, tempo total: 120.70 segundos
# Processado item 74/200, tempo total: 173.43 segundos
# Processado item 75/200, tempo total: 167.95 segundos
# Processado item 76/200, tempo total: 153.79 segundos
# Processado item 77/200, tempo total: 68.46 segundos
# Processado item 78/200, tempo total: 103.75 segundos
# Processado item 79/200, tempo total: 67.93 segundos
# Processado item 80/200, tempo total: 62.74 segundos
# Processado item 81/200, tempo total: 4.97 segundos
# Processado item 82/200, tempo total: 93.92 segundos
# Processado item 83/200, tempo total: 7.91 segundos
# Processado item 84/200, tempo total: 5.13 segundos
# Processado item 85/200, tempo total: 291.74 segundos
# Processado item 86/200, tempo total: 164.70 segundos
# Processado item 87/200, tempo total: 147.02 segundos
# Processado item 88/200, tempo total: 138.53 segundos
# Processado item 89/200, tempo total: 246.72 segundos
# Processado item 90/200, tempo total: 260.24 segundos
# Processado item 91/200, tempo total: 297.52 segundos
# Processado item 92/200, tempo total: 44.08 segundos
# Processado item 93/200, tempo total: 121.22 segundos
# Processado item 94/200, tempo total: 194.72 segundos
# Processado item 95/200, tempo total: 199.88 segundos
# Processado item 96/200, tempo total: 205.93 segundos
# Processado item 97/200, tempo total: 309.25 segundos
# Processado item 98/200, tempo total: 147.00 segundos
# Processado item 99/200, tempo total: 137.38 segundos
# Processado item 100/200, tempo total: 155.43 segundos
# Processado item 101/200, tempo total: 351.93 segundos
# Processado item 102/200, tempo total: 165.88 segundos
# Processado item 104/200, tempo total: 192.27 segundos
# Processado item 105/200, tempo total: 122.19 segundos
# Processado item 106/200, tempo total: 151.40 segundos
# Processado item 107/200, tempo total: 327.38 segundos
# Processado item 108/200, tempo total: 165.73 segundos
# Processado item 109/200, tempo total: 237.75 segundos

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /home/IsabelaGregio/myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
